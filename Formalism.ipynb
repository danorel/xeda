# %%
import chromadb
import copy
import json
import typing as t
import uuid

from chromadb.utils import embedding_functions

from constants import (
    OPENAI_API_KEY,
    VECTOR_STORE_COLLECTION,
    VECTOR_STORE_HOST,
    VECTOR_STORE_PORT
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import chromadb
#       2 import copy
#       3 import json
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
pretrained_embeddings = embedding_functions.OpenAIEmbeddingFunction(
    api_key=OPENAI_API_KEY,
    model_name="text-embedding-ada-002"
)

vector_store = chromadb.HttpClient(
    host=VECTOR_STORE_HOST, 
    port=VECTOR_STORE_PORT
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pretrained_embeddings = embedding_functions.OpenAIEmbeddingFunction(
#       2     api_key=OPENAI_API_KEY,
#       3     model_name="text-embedding-ada-002"
#       4 )
#       6 vector_store = chromadb.HttpClient(
#       7     host=VECTOR_STORE_HOST,
#       8     port=VECTOR_STORE_PORT
#       9 )
#
# NameError: name 'embedding_functions' is not defined

# %%
vector_collection = vector_store.get_collection(VECTOR_STORE_COLLECTION)
